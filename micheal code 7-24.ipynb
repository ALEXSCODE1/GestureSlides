# %%
import cv2
import numpy as np
import pandas as pd
from ultralytics import YOLO
import time
import pyautogui

# Load the YOLO11n-pose model
model = YOLO("yolo11n-pose.pt")

# Initialize webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Define keypoint indices for elbows (based on COCO 17-keypoint format)
LEFT_SHOULDER = 5
RIGHT_SHOULDER = 6
LEFT_ELBOW = 7
RIGHT_ELBOW = 8
LEFT_WRIST = 9
RIGHT_WRIST = 10

last_trigger_time = 0
cooldown = 1.5

# List to store elbow coordinates and timestamps
data = []

cycle = ""

# Process video frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    # Perform pose estimation
    results = model(frame, conf=0.5, classes=[0])  # Detect only person class

    # Get current timestamp
    timestamp = time.time()

    # Process results
    for result in results:
        if hasattr(result, 'keypoints') and result.keypoints is not None:
            keypoints = result.keypoints.xy.cpu().numpy()  # Shape: (num_persons, 17, 2)
            confidences = result.keypoints.conf.cpu().numpy()  # Shape: (num_persons, 17)

            for person_idx, (kpts, confs) in enumerate(zip(keypoints, confidences)):
                # Extract elbow coordinates

                # === RIGHT SHOULDER ===
                if confs[RIGHT_SHOULDER] > 0.5:
                    x, y = kpts[RIGHT_SHOULDER]
                    cv2.circle(frame, (int(x), int(y)), 8, (255, 0, 0), -1)  # Blue

                # === RIGHT ELBOW ===
                if confs[RIGHT_ELBOW] > 0.5:
                    x, y = kpts[RIGHT_ELBOW]
                    cv2.circle(frame, (int(x), int(y)), 8, (0, 255, 0), -1)  # Green

                # === RIGHT WRIST ===
                if confs[RIGHT_WRIST] > 0.5:
                    x, y = kpts[RIGHT_WRIST]
                    cv2.circle(frame, (int(x), int(y)), 8, (0, 0, 255), -1)  # Red

                if confs[LEFT_SHOULDER] > 0.5:
                    x, y = kpts[LEFT_SHOULDER]
                    cv2.circle(frame, (int(x), int(y)), 8, (255, 0, 0), -1)  # Blue

                if confs[LEFT_ELBOW] > 0.5:
                    x, y = kpts[LEFT_ELBOW]
                    cv2.circle(frame, (int(x), int(y)), 8, (0, 255, 0), -1)  # Green

                if confs[LEFT_WRIST] > 0.5:
                    x, y = kpts[LEFT_WRIST]
                    cv2.circle(frame, (int(x), int(y)), 8, (0, 0, 255), -1)  # Red

                # Draw Lines
                if confs[RIGHT_SHOULDER] > 0.5 and confs[RIGHT_ELBOW] > 0.5:
                    cv2.line(frame, tuple(kpts[RIGHT_SHOULDER].astype(int)), tuple(kpts[RIGHT_ELBOW].astype(int)), (100, 100, 255), 2)
                if confs[RIGHT_ELBOW] > 0.5 and confs[RIGHT_WRIST] > 0.5:
                    cv2.line(frame, tuple(kpts[RIGHT_ELBOW].astype(int)), tuple(kpts[RIGHT_WRIST].astype(int)), (100, 100, 255), 2)
                if confs[LEFT_SHOULDER] > 0.5 and confs[LEFT_ELBOW] > 0.5:
                    cv2.line(frame, tuple(kpts[LEFT_SHOULDER].astype(int)), tuple(kpts[LEFT_ELBOW].astype(int)), (100, 100, 255), 2)
                if confs[LEFT_ELBOW] > 0.5 and confs[LEFT_WRIST] > 0.5:
                    cv2.line(frame, tuple(kpts[LEFT_ELBOW].astype(int)), tuple(kpts[LEFT_WRIST].astype(int)), (100, 100, 255), 2)


                if confs[RIGHT_WRIST] > 0.5 and confs[RIGHT_SHOULDER] > 0.5:
                    wrist_y = kpts[RIGHT_WRIST][1]
                    shoulder_y = kpts[RIGHT_SHOULDER][1]

                    if wrist_y < shoulder_y - 40 and time.time() - last_trigger_time > cooldown:
                        pyautogui.press('right')
                        print("Next slide triggered")
                        last_trigger_time = time.time()
                        cycle = "Next"
                
                if confs[LEFT_WRIST] > 0.5 and confs[LEFT_SHOULDER] > 0.5:
                    wrist_y = kpts[LEFT_WRIST][1]
                    shoulder_y = kpts[LEFT_SHOULDER][1]

                    if wrist_y < shoulder_y - 40 and time.time() - last_trigger_time > cooldown:
                        pyautogui.press('left')
                        print("Previous slide triggered")
                        last_trigger_time = time.time()
                        cycle = "Previous"

                if time.time() - last_trigger_time < 1:
                    cv2.putText(frame, cycle + " Slide Triggered", (30, 50), cv2.FONT_HERSHEY_SIMPLEX,
                                1, (0, 0, 255), 3)



    # Display the frame
    cv2.imshow("Elbow Tracking", frame)

    # Break loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 93.5ms
# Speed: 3.6ms preprocess, 93.5ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.0ms
# Speed: 1.2ms preprocess, 44.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 2.3ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.6ms
# Speed: 1.8ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.0ms
# Speed: 1.8ms preprocess, 37.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.9ms
# Speed: 1.8ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.9ms
# Speed: 1.3ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.3ms
# Speed: 0.9ms preprocess, 34.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.8ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.3ms
# Speed: 1.0ms preprocess, 41.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.0ms
# Speed: 1.8ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.1ms
# Speed: 1.1ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.2ms
# Speed: 1.6ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.8ms preprocess, 42.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.6ms
# Speed: 1.9ms preprocess, 44.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.4ms
# Speed: 1.1ms preprocess, 36.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.8ms
# Speed: 1.9ms preprocess, 43.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.8ms
# Speed: 1.4ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.2ms
# Speed: 1.8ms preprocess, 45.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 2.2ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Speed: 2.2ms preprocess, 41.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.5ms
# Speed: 1.1ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.6ms
# Speed: 1.9ms preprocess, 44.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.8ms
# Speed: 1.1ms preprocess, 40.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.1ms
# Speed: 1.1ms preprocess, 45.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.3ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Previous slide triggered
#
# 0: 480x640 1 person, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.2ms
# Speed: 2.2ms preprocess, 43.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.5ms
# Speed: 1.1ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.3ms
# Speed: 1.3ms preprocess, 50.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.7ms
# Speed: 1.7ms preprocess, 48.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.2ms preprocess, 41.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.6ms
# Speed: 1.5ms preprocess, 46.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.3ms
# Speed: 2.4ms preprocess, 45.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 49.2ms
# Speed: 1.5ms preprocess, 49.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Previous slide triggered
#
# 0: 480x640 2 persons, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.0ms
# Speed: 1.1ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.2ms
# Speed: 0.9ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.8ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.3ms
# Speed: 1.2ms preprocess, 37.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.9ms
# Speed: 0.9ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.1ms
# Speed: 0.9ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.5ms
# Speed: 0.9ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 0.9ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Next slide triggered
#
# 0: 480x640 1 person, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.1ms
# Speed: 0.9ms preprocess, 37.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.8ms
# Speed: 0.9ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.0ms
# Speed: 1.5ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.2ms
# Speed: 0.9ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.4ms
# Speed: 0.9ms preprocess, 37.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.0ms
# Speed: 1.7ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.1ms
# Speed: 0.9ms preprocess, 36.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.8ms
# Speed: 0.9ms preprocess, 33.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.3ms
# Speed: 1.0ms preprocess, 34.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Previous slide triggered
#
# 0: 480x640 1 person, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.6ms
# Speed: 1.8ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.3ms
# Speed: 0.9ms preprocess, 40.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.1ms
# Speed: 1.0ms preprocess, 34.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.8ms
# Speed: 1.1ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Next slide triggered
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.2ms
# Speed: 1.1ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 0.9ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.0ms
# Speed: 1.0ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.6ms
# Speed: 0.9ms preprocess, 43.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.7ms
# Speed: 1.1ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 0.9ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 1.1ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.7ms
# Speed: 0.9ms preprocess, 35.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Next slide triggered
#
# 0: 480x640 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.7ms
# Speed: 1.1ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 1.1ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.8ms
# Speed: 0.9ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.6ms
# Speed: 1.8ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.6ms
# Speed: 1.8ms preprocess, 34.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.2ms
# Speed: 1.8ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Next slide triggered
#
# 0: 480x640 1 person, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.0ms
# Speed: 1.2ms preprocess, 38.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.7ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 0.9ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.8ms
# Speed: 1.8ms preprocess, 35.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.0ms
# Speed: 1.1ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.0ms
# Speed: 2.3ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.2ms
# Speed: 1.1ms preprocess, 38.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.0ms
# Speed: 0.9ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Previous slide triggered
#
# 0: 480x640 1 person, 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.9ms
# Speed: 1.8ms preprocess, 35.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.2ms
# Speed: 1.1ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.4ms
# Speed: 1.1ms preprocess, 38.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.5ms
# Speed: 1.1ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.3ms
# Speed: 0.9ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.2ms
# Speed: 1.1ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.6ms
# Speed: 0.9ms preprocess, 34.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.6ms
# Speed: 0.9ms preprocess, 34.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 0.9ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.3ms
# Speed: 2.1ms preprocess, 40.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.1ms
# Speed: 1.1ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.0ms
# Speed: 1.7ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.2ms
# Speed: 1.7ms preprocess, 34.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.1ms
# Speed: 1.8ms preprocess, 36.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Previous slide triggered
#
# 0: 480x640 1 person, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 35.1ms
# Speed: 0.9ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 34.9ms
# Speed: 0.9ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.8ms
# Speed: 0.9ms preprocess, 39.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.6ms
# Speed: 1.1ms preprocess, 34.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.3ms
# Speed: 1.1ms preprocess, 37.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.9ms
# Speed: 1.6ms preprocess, 46.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.3ms
# Speed: 0.9ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.8ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Next slide triggered
#
# 0: 480x640 1 person, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.0ms
# Speed: 0.9ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.0ms
# Speed: 1.0ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.1ms
# Speed: 0.9ms preprocess, 38.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.3ms
# Speed: 1.0ms preprocess, 34.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.0ms
# Speed: 1.7ms preprocess, 38.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.3ms
# Speed: 1.1ms preprocess, 37.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.1ms
# Speed: 1.1ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.7ms
# Speed: 1.6ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.7ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Next slide triggered
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.4ms
# Speed: 1.8ms preprocess, 38.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.2ms
# Speed: 1.7ms preprocess, 38.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.0ms
# Speed: 1.7ms preprocess, 48.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.7ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.9ms
# Speed: 1.1ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 33.6ms
# Speed: 0.9ms preprocess, 33.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.1ms
# Speed: 1.8ms preprocess, 37.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Next slide triggered
#
# 0: 480x640 1 person, 35.7ms
# Speed: 1.8ms preprocess, 35.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.5ms
# Speed: 1.2ms preprocess, 38.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.5ms
# ...
#
# 0: 480x640 1 person, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.1ms
# Speed: 0.9ms preprocess, 36.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Previous slide triggered
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.6ms
# Speed: 1.9ms preprocess, 36.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.1ms
# Speed: 0.9ms preprocess, 38.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.1ms
# Speed: 1.1ms preprocess, 36.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.8ms
# Speed: 0.9ms preprocess, 36.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 0.9ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.7ms
# Speed: 0.9ms preprocess, 35.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Previous slide triggered
#
# 0: 480x640 1 person, 36.0ms
# Speed: 1.1ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.4ms
# Speed: 1.1ms preprocess, 34.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.8ms
# Speed: 1.7ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.0ms
# Speed: 1.8ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.7ms
# Speed: 1.9ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.0ms
# Speed: 1.1ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.0ms
# Speed: 1.0ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.4ms
# Speed: 0.9ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.3ms
# Speed: 1.9ms preprocess, 47.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 44.1ms
# Speed: 0.9ms preprocess, 44.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.8ms
# Speed: 0.9ms preprocess, 35.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.6ms
# Speed: 0.9ms preprocess, 36.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.8ms
# Speed: 0.9ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.8ms
# Speed: 0.9ms preprocess, 34.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.8ms
# Speed: 0.9ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.3ms
# Speed: 0.9ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.0ms
# Speed: 1.5ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.1ms
# Speed: 1.1ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.3ms
# Speed: 1.8ms preprocess, 35.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 38.5ms
# Speed: 1.6ms preprocess, 38.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.8ms
# Speed: 1.0ms preprocess, 37.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 0.9ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 46.0ms
# Speed: 1.1ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 48.9ms
# Speed: 0.9ms preprocess, 48.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.6ms
# Speed: 1.8ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 37.6ms
# Speed: 0.9ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.0ms
# Speed: 1.1ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.7ms
# Speed: 1.1ms preprocess, 36.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 36.6ms
# Speed: 0.9ms preprocess, 36.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.7ms
# Speed: 1.8ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.6ms
# Speed: 0.9ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.7ms
# Speed: 0.9ms preprocess, 35.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.5ms
# Speed: 1.1ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.6ms
# Speed: 1.8ms preprocess, 35.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 34.9ms
# Speed: 0.9ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
